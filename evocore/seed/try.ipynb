# %%
from langchain_ollama.chat_models import ChatOllama

llm = ChatOllama(model="llama3.1:8b", temperature=0.2)
llm.invoke('who are you?').content
# Out:
# 'I\'m an artificial intelligence model known as Llama. Llama stands for "Large Language Model Meta AI."'

# %%
from importlib import reload
from prompts import architect_prompt, format_instructions




prompt = architect_prompt.format(format_instructions=format_instructions)
prompt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from prompts import architect_prompt, format_instructions
#       4 prompt = architect_prompt.format(format_instructions=format_instructions)
#       5 prompt
#
# ImportError: cannot import name 'format_instructions' from 'prompts' (/home/liam/Documents/EvoCore/evocore/seed/prompts.py)
